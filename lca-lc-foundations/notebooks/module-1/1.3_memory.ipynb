# %%
from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "gpt-5-nano"
)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 from langchain.agents import create_agent
# ----> 4 agent = create_agent(
#       5     "gpt-5-nano"
#       6 )
#
# File ~/Git Repos/gdg-mum-langchain-project/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain/agents/factory.py:801, in create_agent(model, tools, system_prompt, middleware, response_format, state_schema, context_schema, checkpointer, store, interrupt_before, interrupt_after, debug, name, cache)
#     799 # init chat model
#     800 if isinstance(model, str):
# --> 801     model = init_chat_model(model)
#     803 # Convert system_prompt to SystemMessage if needed
#     804 system_message: SystemMessage | None = None
#
# File ~/Git Repos/gdg-mum-langchain-project/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain/chat_models/base.py:464, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     456     warnings.warn(
#     457         f"{config_prefix=} has been set but no fields are configurable. Set "
#     458         f"`configurable_fields=(...)` to specify the model params that are "
#     459         f"configurable.",
#     460         stacklevel=2,
#     461     )
#     463 if not configurable_fields:
# --> 464     return _init_chat_model_helper(
#     465         cast("str", model),
#     466         model_provider=model_provider,
#     467         **kwargs,
#     468     )
#     469 if model:
#     470     kwargs["model"] = model
#
# File ~/Git Repos/gdg-mum-langchain-project/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain/chat_models/base.py:488, in _init_chat_model_helper(model, model_provider, **kwargs)
#     486 model, model_provider = _parse_model(model, model_provider)
#     487 creator_func = _get_chat_model_creator(model_provider)
# --> 488 return creator_func(model=model, **kwargs)
#
# File ~/Git Repos/gdg-mum-langchain-project/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain/chat_models/base.py:35, in _call(cls, **kwargs)
#      33 def _call(cls: type[BaseChatModel], **kwargs: Any) -> BaseChatModel:
#      34     # TODO: replace with operator.call when lower bounding to Python 3.11
# ---> 35     return cls(**kwargs)
#
# File ~/Git Repos/gdg-mum-langchain-project/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/load/serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/Git Repos/gdg-mum-langchain-project/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1105, in BaseChatOpenAI.validate_environment(self)
#    1095         self.http_async_client = httpx.AsyncClient(
#    1096             proxy=self.openai_proxy, verify=global_ssl_context
#    1097         )
#    1098     async_specific = {
#    1099         "http_client": self.http_async_client
#    1100         or _get_default_async_httpx_client(
#    (...)   1103         "api_key": async_api_key_value,
#    1104     }
# -> 1105     self.root_async_client = openai.AsyncOpenAI(
#    1106         **client_params,
#    1107         **async_specific,  # type: ignore[arg-type]
#    1108     )
#    1109     self.async_client = self.root_async_client.chat.completions
#    1110 return self
#
# File ~/Git Repos/gdg-mum-langchain-project/lca-lc-foundations/.venv/lib/python3.12/site-packages/openai/_client.py:514, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     512     api_key = os.environ.get("OPENAI_API_KEY")
#     513 if api_key is None:
# --> 514     raise OpenAIError(
#     515         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     516     )
#     517 if callable(api_key):
#     518     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "gpt-5-nano",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
